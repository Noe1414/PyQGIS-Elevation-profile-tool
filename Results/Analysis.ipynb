# %% [markdown]
# # Data Analysis
#
# ### The goal in this notebook is to compare the data we got with the API to the original data

# %% [markdown]
# The data is a 10km course recorded with a garmin watch. The course coordinates have been extracted and used to calculate the elevation. The elevation calculated is then compared to the original one.
# The *df1* dataset is the calculated one. the *df2* is the original data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("C:/Users/Noe_S/Documents/Travail/Git/Elevation_profile_tool/Shapefile test/profil_0.csv", sep=";")
df2 = pd.read_csv("C:/Users/Noe_S/Documents/Travail/Git/Elevation_profile_tool/Shapefile test/profil_comparaison.csv", sep=",")

# %%
df1.head()
# Out:
#    Unnamed: 0          0       1
# 0           0   0.000000  517.15
# 1           1   4.814210  517.05
# 2           2   7.493064  517.70
# 3           3   9.751963  517.15
# 4           4  12.847800  517.15

# %%
df2.head()
# Out:
#    track_fid  track_seg_id  track_seg_point_id         ele  \
# 0          0             0                   0  513.200012
# 1          0             0                   1  513.200012
# 2          0             0                   2  512.599976
# 3          0             0                   3  512.400024
# 4          0             0                   4  512.000000
#
#                      time  magvar  geoidheight  name  cmt  desc  ...  \
# 0  2023/10/20 11:50:13+00     NaN          NaN   NaN  NaN   NaN  ...
# 1  2023/10/20 11:50:14+00     NaN          NaN   NaN  NaN   NaN  ...
# 2  2023/10/20 11:50:16+00     NaN          NaN   NaN  NaN   NaN  ...
# 3  2023/10/20 11:50:17+00     NaN          NaN   NaN  NaN   NaN  ...
# 4  2023/10/20 11:50:18+00     NaN          NaN   NaN  NaN   NaN  ...
#
#    link2_type  sym  type  fix  sat  hdop  vdop  pdop  ageofdgpsdata  dgpsid
# 0         NaN  NaN   NaN  NaN  NaN   NaN   NaN   NaN            NaN     NaN
# ...

# %%
plt.figure(figsize=(16,9))
plt.plot(df1['Unnamed: 0'],df1['1'])
plt.plot(df2['track_seg_point_id'],df2['ele'])
plt.xlabel('Number of points')
plt.ylabel('Altitude (m)')
plt.grid()
plt.legend(['original data','tool data'])
